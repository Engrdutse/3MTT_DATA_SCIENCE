# %% [markdown]
# # importing Pandas library

# %%
import pandas as pd

# %%
messy_data = pd.read_csv('Airbnb_India_Top_500.csv')

# %%
messy_data.head(5)
# Out:
#                             address  isHostedBySuperhost  location/lat  \
# 0   Manali, Himachal Pradesh, India                False      32.22330
# 1   Manali, Himachal Pradesh, India                False      32.22352
# 2                        Goa, India                False      15.50400
# 3  Bhuntar, Himachal Pradesh, India                False      31.88656
# 4          Jaipur, Rajasthan, India                False      26.85991
#
#    location/lng                                              name  \
# 0      77.18228                        HighQ Manali / Deluxe Room
# 1      77.18152                      Highq manali / 3 BHK Cottage
# 2      73.86600       Best view of the river from your terrace 04
# 3      77.14467                                          Shabashe
# 4      75.66909  Luxurious Independent Studio with Wifi & Kitchen
#
#    numberOfGuests  pricing/rate/amount                    roomType  stars
# 0               3                 8946               Room in hotel    NaN
# 1               9                 9124               Room in hotel    NaN
# 2               4                 9900        Private room in home   4.00
# 3               1                 8684  Shared room in rental unit    NaN
# 4               1                20690                Entire condo   4.75

# %%
#Check for missing values:

# %%
print(messy_data.isnull().sum())
# Out:
# address                  0
# isHostedBySuperhost      0
# location/lat             0
# location/lng             0
# name                     0
# numberOfGuests           0
# pricing/rate/amount      0
# roomType                 0
# stars                  304
# dtype: int64

# %%
messy_data.tail(5)
# Out:
#                               address  isHostedBySuperhost  location/lat  \
# 495       Nalambi, Maharashtra, India                 True      19.22775
# 496      Sughandhagiry, Kerala, India                False      11.58006
# 497  Chalnichhina, Uttarakhand, India                 True      29.55470
# 498                        Goa, India                 True      15.59870
# 499             Munnar, Kerala, India                False      10.15926
#
#      location/lng                                               name  \
# 495      73.21889                        Jumbo pool villa, Ambernath
# 496      75.99667          A Frame Wildrootstay Orchid Family Chalet
# 497      79.80569  Hushstay x House on the Slope :Facing the Hima...
# 498      73.75698       Vagator ,Cosy & Modern 3 bedroom villa for 8
# 499      77.17119       Nature Castle(Willus villa),Munnar,Vattavada
#
#      numberOfGuests  pricing/rate/amount      roomType  stars
# 495              12                  152     Farm stay   4.80
# 496               6                  131     Farm stay   3.80
# 497               6                  192     Farm stay   5.00
# 498               8                  196  Entire villa   5.00
# 499              16                  154  Entire villa   4.53

# %%
list(messy_data.columns)
# Out:
# ['address',
#  'isHostedBySuperhost',
#  'location/lat',
#  'location/lng',
#  'name',
#  'numberOfGuests',
#  'pricing/rate/amount',
#  'roomType',
#  'stars']

# %%
#Creating a copy of the messy data for cleaning

# %%
data1 = messy_data.copy()

# %%
data1.head(5)
# Out:
#                             address  isHostedBySuperhost  location/lat  \
# 0   Manali, Himachal Pradesh, India                False      32.22330
# 1   Manali, Himachal Pradesh, India                False      32.22352
# 2                        Goa, India                False      15.50400
# 3  Bhuntar, Himachal Pradesh, India                False      31.88656
# 4          Jaipur, Rajasthan, India                False      26.85991
#
#    location/lng                                              name  \
# 0      77.18228                        HighQ Manali / Deluxe Room
# 1      77.18152                      Highq manali / 3 BHK Cottage
# 2      73.86600       Best view of the river from your terrace 04
# 3      77.14467                                          Shabashe
# 4      75.66909  Luxurious Independent Studio with Wifi & Kitchen
#
#    numberOfGuests  pricing/rate/amount                    roomType  stars
# 0               3                 8946               Room in hotel    NaN
# 1               9                 9124               Room in hotel    NaN
# 2               4                 9900        Private room in home   4.00
# 3               1                 8684  Shared room in rental unit    NaN
# 4               1                20690                Entire condo   4.75

# %% [markdown]
# #Renaming Columns Names

# %%
data1 = data1.rename(columns={'numberOfGuests': 'Accommodation capacity'})

# %%
clean_data1.head(3)
# Out:
#                            Address  location/lat  location/lng  \
# 0  Manali, Himachal Pradesh, India      32.22330      77.18228
# 1  Manali, Himachal Pradesh, India      32.22352      77.18152
# 2                       Goa, India      15.50400      73.86600
#
#                           Title of the Listing  Accommodation capacity  \
# 0                   HighQ Manali / Deluxe Room                       3
# 1                 Highq manali / 3 BHK Cottage                       9
# 2  Best view of the river from your terrace 04                       4
#
#    pricing/rate/amount              roomType  Rating
# 0                 8946         Room in hotel     NaN
# 1                 9124         Room in hotel     NaN
# 2                 9900  Private room in home     4.0

# %%
data1 = data1.rename(columns={'name': 'Title of the Listing'})

# %%
data1.head(3)
# Out:
#                            address  isHostedBySuperhost  location/lat  \
# 0  Manali, Himachal Pradesh, India                False      32.22330
# 1  Manali, Himachal Pradesh, India                False      32.22352
# 2                       Goa, India                False      15.50400
#
#    location/lng                         Title of the Listing  \
# 0      77.18228                   HighQ Manali / Deluxe Room
# 1      77.18152                 Highq manali / 3 BHK Cottage
# 2      73.86600  Best view of the river from your terrace 04
#
#    Accommodation capacity  pricing/rate/amount              roomType  stars
# 0                       3                 8946         Room in hotel    NaN
# 1                       9                 9124         Room in hotel    NaN
# 2                       4                 9900  Private room in home    4.0

# %%
data1 = data1.rename(columns={'stars': 'Rating', 'address': 'Address'})

# %%
data1.head(5)
# Out:
#                             Address  isHostedBySuperhost  location/lat  \
# 0   Manali, Himachal Pradesh, India                False      32.22330
# 1   Manali, Himachal Pradesh, India                False      32.22352
# 2                        Goa, India                False      15.50400
# 3  Bhuntar, Himachal Pradesh, India                False      31.88656
# 4          Jaipur, Rajasthan, India                False      26.85991
#
#    location/lng                              Title of the Listing  \
# 0      77.18228                        HighQ Manali / Deluxe Room
# 1      77.18152                      Highq manali / 3 BHK Cottage
# 2      73.86600       Best view of the river from your terrace 04
# 3      77.14467                                          Shabashe
# 4      75.66909  Luxurious Independent Studio with Wifi & Kitchen
#
#    Accommodation capacity  pricing/rate/amount                    roomType  \
# 0                       3                 8946               Room in hotel
# 1                       9                 9124               Room in hotel
# 2                       4                 9900        Private room in home
# 3                       1                 8684  Shared room in rental unit
# 4                       1                20690                Entire condo
#
#    Rating
# 0     NaN
# 1     NaN
# 2    4.00
# 3     NaN
# 4    4.75

# %%
#Remove irrelevant columns:

# %%
data1.drop(['isHostedBySuperhost'], axis=1, inplace=True)

# %%
data1.head(3)
# Out:
#                            Address  location/lat  location/lng  \
# 0  Manali, Himachal Pradesh, India      32.22330      77.18228
# 1  Manali, Himachal Pradesh, India      32.22352      77.18152
# 2                       Goa, India      15.50400      73.86600
#
#                           Title of the Listing  Accommodation capacity  \
# 0                   HighQ Manali / Deluxe Room                       3
# 1                 Highq manali / 3 BHK Cottage                       9
# 2  Best view of the river from your terrace 04                       4
#
#    pricing/rate/amount              roomType  Rating
# 0                 8946         Room in hotel     NaN
# 1                 9124         Room in hotel     NaN
# 2                 9900  Private room in home     4.0

# %% [markdown]
# # Filling the missing data in Rating Column

# %%
data1['Rating'].head(5)
# Out:
# 0     NaN
# 1     NaN
# 2    4.00
# 3     NaN
# 4    4.75
# Name: Rating, dtype: float64

# %%
#To calculate the average Star rating we import Numerical python 'Numpy'

# %%
import numpy as np

# %%
data1["Rating"].mean()
# Out:
# 4.650204081632651

# %%
avr_rating = data1["Rating"].mean()

# %%
#Using average to fill the missing Rating column data

# %%
avr_rating
# Out:
# 4.650204081632651

# %%
data1['Rating'].fillna(value=avr_rating, inplace=True)

# %%
data1.head(3)
# Out:
#                            Address  location/lat  location/lng  \
# 0  Manali, Himachal Pradesh, India      32.22330      77.18228
# 1  Manali, Himachal Pradesh, India      32.22352      77.18152
# 2                       Goa, India      15.50400      73.86600
#
#                           Title of the Listing  Accommodation capacity  \
# 0                   HighQ Manali / Deluxe Room                       3
# 1                 Highq manali / 3 BHK Cottage                       9
# 2  Best view of the river from your terrace 04                       4
#
#    pricing/rate/amount              roomType    Rating
# 0                 8946         Room in hotel  4.650204
# 1                 9124         Room in hotel  4.650204
# 2                 9900  Private room in home  4.000000

# %%
print(data1.isnull().sum())
# Out:
# Address                   0
# location/lat              0
# location/lng              0
# Title of the Listing      0
# Accommodation capacity    0
# pricing/rate/amount       0
# roomType                  0
# Rating                    0
# dtype: int64

# %%
#Now our data1 is clean

# %%
# hence lets copy the data to clean container

# %%
clean_data = data1.copy()

# %%
clean_data.head(20)
# Out:
#                              Address  location/lat  location/lng  \
# 0    Manali, Himachal Pradesh, India      32.22330      77.18228
# 1    Manali, Himachal Pradesh, India      32.22352      77.18152
# 2                         Goa, India      15.50400      73.86600
# 3   Bhuntar, Himachal Pradesh, India      31.88656      77.14467
# 4           Jaipur, Rajasthan, India      26.85991      75.66909
# 5   Bhuntar, Himachal Pradesh, India      32.01248      77.29114
# 6   Bhuntar, Himachal Pradesh, India      32.01204      77.29090
# 7           Gurugram, Haryana, India      28.36673      77.00647
# 8         Ganaheda, Rajasthan, India      26.49372      74.53830
# 9    Banjar, Himachal Pradesh, India      31.63839      77.34503
# 10                Morjim, Goa, India      15.62707      73.73270
# 11          Gurugram, Haryana, India      28.35517      77.00426
# 12          Awas, Maharashtra, India      18.76514      72.87878
# 13       Bengaluru, Karnataka, India      13.12752      77.56391
# 14              Sangolda, Goa, India      15.54799      73.81177
# 15     Rishikesh, Uttarakhand, India      30.13704      78.30683
# 16                 Parra, Goa, India      15.57329      73.77670
# 17           New Delhi, Delhi, India      28.49600      77.16600
# 18                        Aru, India      34.09091      75.26407
# 19             North Goa, Goa, India      15.56203      73.78613
#
#                                  Title of the Listing  Accommodation capacity  \
# 0                          HighQ Manali / Deluxe Room                       3
# 1                        Highq manali / 3 BHK Cottage                       9
# 2         Best view of the river from your terrace 04                       4
# 3                                            Shabashe                       1
# 4    Luxurious Independent Studio with Wifi & Kitchen                       1
# 5   Aman Palace Guest House Kasol With Super Delux...                       3
# 6      Aman Palace Guest House Kasol With Deluxe Room                       2
# 7   Boutique destination wedding experience  50pax...                      16
# 8                   Lux farm resort with pool - Villa                      12
# 9                                         Deluxe Room                       3
# 10                     Vedatmana By The Waves, Morjim                      12
# 11      Marriage  Or Party Full Resort For 30 Persons                      16
# 12          StayVista - Pranaam - 6Bhk Luxury Alibaug                      15
# 13    Luxury PoolSide Heritage Villa in Lap of Nature                      16
# 14  12 BR Mansion | Big Groups | Private Pool | Sc...                      16
# 15  An extravagant Pushp villa overlooking the Ganges                       8
# 16  Perfect for Big Groups! 8BR Villa w Pool in Parra                      16
# 17              Brookwood Gardens Wedding Guest Rooms                      16
# 18                Pahalgham Cottage Next to the River                      10
# 19    Crystal Village 10 Bedroom Pvt Pool villa Nagoa                      16
#
#     pricing/rate/amount                    roomType    Rating
# 0                  8946               Room in hotel  4.650204
# 1                  9124               Room in hotel  4.650204
# 2                  9900        Private room in home  4.000000
# 3                  8684  Shared room in rental unit  4.650204
# 4                 20690                Entire condo  4.750000
# 5                  4274               Room in hotel  4.650204
# 6                  4274               Room in hotel  4.650204
# 7                  1734                   Farm stay  4.650204
# 8                  1804                   Farm stay  4.650204
# 9                  2822               Room in hotel  4.650204
# 10                  902                Entire villa  4.650204
# 11                 1443                   Farm stay  4.650204
# 12                  912                Entire villa  4.650204
# 13                  882      Private room in resort  4.650204
# 14                 1374                Entire villa  4.650204
# 15                  788                Entire villa  4.650204
# 16                  978                Entire villa  4.650204
# 17                  962                   Farm stay  4.650204
# 18                  782              Entire cottage  4.650204
# 19                  854                 Entire home  4.650204
